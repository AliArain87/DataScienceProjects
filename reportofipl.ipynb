# %%
import pandas as pd
from pandas_profiling import ProfileReport

df = pd.read_csv('IPL.csv')
df = df.sample(1)
profile = ProfileReport(df)
#profile.to_file(output_file='IPL.html')
df.sample(100)
# Out:
#           id           city        date  ... method          umpire1         umpire2
# 42    336024      Hyderabad  2008-05-18  ...    NaN      BR Doctrove       DJ Harper
# 515   829821         Ranchi  2015-05-22  ...    NaN     AK Chaudhary     CB Gaffaney
# 465   829719      Bangalore  2015-04-13  ...    NaN     RM Deshpande  RK Illingworth
# 556   980979  Visakhapatnam  2016-05-10  ...    NaN      CB Gaffaney       VK Sharma
# 675  1136600         Jaipur  2018-05-08  ...    NaN        M Erasmus     Nitin Menon
# ..       ...            ...         ...  ...    ...              ...             ...
# 564   980995        Kolkata  2016-05-16  ...    NaN      CB Gaffaney  A Nand Kishore
# 50    336033        Chennai  2008-05-24  ...    NaN        DJ Harper      SL Shastri
# 40    336022          Delhi  2008-05-17  ...    D/L   AV Jayaprakash     RE Koertzen
# 692  1136617         Mumbai  2018-05-22  ...    NaN    C Shamshuddin       M Erasmus
# 511   829813      Bangalore  2015-05-17  ...    NaN  HDPK Dharmasena    K Srinivasan
#
# [100 rows x 17 columns]
